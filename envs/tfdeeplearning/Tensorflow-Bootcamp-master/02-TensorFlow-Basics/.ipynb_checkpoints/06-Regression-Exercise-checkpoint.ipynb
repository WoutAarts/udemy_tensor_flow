# %% [markdown]
# # Regression Exercise
#
# California Housing Data
#
# This data set contains information about all the block groups in California from the 1990 Census. In this sample a block group on average includes 1425.5 individuals living in a geographically compact area.
#
# The task is to aproximate the median house value of each block from the values of the rest of the variables.
#
#  It has been obtained from the LIACC repository. The original page where the data set can be found is: http://www.liaad.up.pt/~ltorgo/Regression/DataSets.html.

# %% [markdown]
# The Features:
#
# * housingMedianAge: continuous.
# * totalRooms: continuous.
# * totalBedrooms: continuous.
# * population: continuous.
# * households: continuous.
# * medianIncome: continuous.
# * medianHouseValue: continuous.

# %% [markdown]
# ## The Data

# %% [markdown]
# ** Import the cal_housing_clean.csv file with pandas. Separate it into a training (70%) and testing set(30%).**

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
df_cal = pd.read_csv('/home/wout/anaconda3/envs/tfdeeplearning/Tensorflow-Bootcamp-master/02-TensorFlow-Basics/cal_housing_clean.csv')

# %%
df_cal.head(2)
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0              41.0       880.0          129.0       322.0       126.0
# 1              21.0      7099.0         1106.0      2401.0      1138.0
#
#    medianIncome  medianHouseValue
# 0        8.3252          452600.0
# 1        8.3014          358500.0

# %%
x_data = df_cal.drop('medianHouseValue', axis=1)
labels = df_cal.medianHouseValue

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size=0.3, random_state=101)

# %%
X_train.head(2)
# Out:
#       housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 6761              19.0      2742.0          756.0      1396.0       703.0
# 3010              32.0       444.0          102.0       242.0        87.0
#
#       medianIncome
# 6761        2.5663
# 3010        1.1528

# %%
y_test.head(2)
# Out:
# 16086    406200.0
# 8816     500001.0
# Name: medianHouseValue, dtype: float64

# %%
X_train.describe()
# Out:
#        housingMedianAge    totalRooms  totalBedrooms    population  \
# count      14448.000000  14448.000000   14448.000000  14448.000000
# mean          28.618217   2638.276647     538.280523   1427.767857
# std           12.591197   2218.951657     428.349613   1133.922834
# min            1.000000      2.000000       1.000000      3.000000
# 25%           18.000000   1443.000000     295.000000    787.000000
# 50%           29.000000   2127.000000     434.500000   1165.000000
# 75%           37.000000   3152.250000     647.250000   1720.000000
# max           52.000000  39320.000000    6445.000000  28566.000000
#
#          households  medianIncome
# count  14448.000000  14448.000000
# mean     500.118079      3.871372
# std      388.203048      1.885517
# min        1.000000      0.499900
# 25%      279.000000      2.572475
# 50%      410.000000      3.532450
# 75%      605.000000      4.750000
# max     6082.000000     15.000100

# %%
# Out:
#                     count           mean            std         min  \
# housingMedianAge  20640.0      28.639486      12.585558      1.0000
# totalRooms        20640.0    2635.763081    2181.615252      2.0000
# totalBedrooms     20640.0     537.898014     421.247906      1.0000
# population        20640.0    1425.476744    1132.462122      3.0000
# households        20640.0     499.539680     382.329753      1.0000
# medianIncome      20640.0       3.870671       1.899822      0.4999
# medianHouseValue  20640.0  206855.816909  115395.615874  14999.0000
#
#                           25%          50%           75%          max
# housingMedianAge      18.0000      29.0000      37.00000      52.0000
# totalRooms          1447.7500    2127.0000    3148.00000   39320.0000
# totalBedrooms        295.0000     435.0000     647.00000    6445.0000
# population           787.0000    1166.0000    1725.00000   35682.0000
# households           280.0000     409.0000     605.00000    6082.0000
# ...

# %% [markdown]
# ### Scale the Feature Data
#
# ** Use sklearn preprocessing to create a MinMaxScaler for the feature data. Fit this scaler only to the training data. Then use it to transform X_test and X_train. Then use the scaled X_test and X_train along with pd.Dataframe to re-create two dataframes of scaled data.**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
X_train_scaled = pd.DataFrame(scaler.transform(X_train))
X_test_scaled = pd.DataFrame(scaler.transform(X_test))

# %%
X_train_scaled.columns = X_train.columns
X_test_scaled.columns = X_test.columns

# %%
X_train_scaled.head(2)
# Out:
#    housingMedianAge  totalRooms  totalBedrooms  population  households  \
# 0          0.352941    0.069688       0.117163    0.048769    0.115442
# 1          0.607843    0.011242       0.015673    0.008367    0.014142
#
#    medianIncome
# 0      0.142508
# 1      0.045027

# %% [markdown]
# ### Create Feature Columns
#
# ** Create the necessary tf.feature_column objects for the estimator. They should all be trated as continuous numeric_columns. **

# %%
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
house_age = tf.feature_column.numeric_column('housingMedianAge')
num_rooms = tf.feature_column.numeric_column('totalRooms')
num_bedrooms = tf.feature_column.numeric_column('totalBedrooms')
popul = tf.feature_column.numeric_column('population')
households = tf.feature_column.numeric_column('households')
income = tf.feature_column.numeric_column('medianIncome')

# %%
feature_cols = [house_age, num_rooms, num_bedrooms, popul, households, income]

# %% [markdown]
# ** Create the input function for the estimator object. (play around with batch_size and num_epochs)**

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train, y_train, batch_size=500, num_epochs=1000, shuffle=True)

# %% [markdown]
# ** Create the estimator model. Use a DNNRegressor. Play around with the hidden units! **

# %%
model = tf.estimator.DNNRegressor([6,12,12,6,6], feature_columns=feature_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpp2g029dk
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpp2g029dk', '_log_step_count_steps': 100, '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None}

# %% [markdown]
# ##### ** Train the model for ~1,000 steps. (Later come back to this and train it for more and check for improvement) **

# %%
model.train(input_fn=input_func, steps=5000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpp2g029dk/model.ckpt.
# INFO:tensorflow:step = 1, loss = 2.87693e+13
# INFO:tensorflow:global_step/sec: 375.265
# INFO:tensorflow:step = 101, loss = 1.31828e+13 (0.266 sec)
# INFO:tensorflow:global_step/sec: 373.393
# INFO:tensorflow:step = 201, loss = 1.40809e+13 (0.269 sec)
# INFO:tensorflow:global_step/sec: 366.21
# INFO:tensorflow:step = 301, loss = 1.16134e+13 (0.272 sec)
# INFO:tensorflow:global_step/sec: 352.115
# INFO:tensorflow:step = 401, loss = 1.26618e+13 (0.285 sec)
# INFO:tensorflow:global_step/sec: 348.35
# INFO:tensorflow:step = 501, loss = 9.76276e+12 (0.286 sec)
# INFO:tensorflow:global_step/sec: 357.822
# INFO:tensorflow:step = 601, loss = 5.7643e+12 (0.280 sec)
# INFO:tensorflow:global_step/sec: 371.976
# INFO:tensorflow:step = 701, loss = 5.19271e+12 (0.268 sec)
# INFO:tensorflow:global_step/sec: 341.151
# INFO:tensorflow:step = 801, loss = 5.51854e+12 (0.293 sec)
# ...

# %%
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Marcial\AppData\Local\Temp\tmp244d0d44\model.ckpt.
# INFO:tensorflow:step = 1, loss = 5.68896e+11
# INFO:tensorflow:global_step/sec: 581.528
# INFO:tensorflow:step = 101, loss = 5.52951e+11 (0.172 sec)
# INFO:tensorflow:global_step/sec: 611.865
# INFO:tensorflow:step = 201, loss = 5.91057e+11 (0.163 sec)
# INFO:tensorflow:global_step/sec: 619.467
# INFO:tensorflow:step = 301, loss = 5.48503e+11 (0.162 sec)
# INFO:tensorflow:global_step/sec: 683.11
# INFO:tensorflow:step = 401, loss = 1.96651e+11 (0.146 sec)
# INFO:tensorflow:global_step/sec: 671.59
# INFO:tensorflow:step = 501, loss = 3.18206e+11 (0.149 sec)
# INFO:tensorflow:global_step/sec: 680.779
# INFO:tensorflow:step = 601, loss = 7.34722e+11 (0.147 sec)
# INFO:tensorflow:global_step/sec: 683.111
# INFO:tensorflow:step = 701, loss = 6.52219e+11 (0.146 sec)
# INFO:tensorflow:global_step/sec: 641.376
# ...

# %% [markdown]
# ** Create a prediction input function and then use the .predict method off your estimator model to create a list or predictions on your test data. **

# %%
prediction_input_func = tf.estimator.inputs.pandas_input_fn(X_test, 
                                                     batch_size=10,
                                                     num_epochs=1,
                                                     shuffle=False)

# %%
predictions = model.predict(prediction_input_func)

# %%
predictions
# Out:
# <generator object Estimator.predict at 0x7f0d84047ca8>

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tmpp2g029dk/model.ckpt-5000

# %%
my_pred
# Out:
# [{'predictions': array([ 315692.09375], dtype=float32)},
#  {'predictions': array([ 395970.3125], dtype=float32)},
#  {'predictions': array([ 184837.015625], dtype=float32)},
#  {'predictions': array([ 144944.96875], dtype=float32)},
#  {'predictions': array([ 451692.15625], dtype=float32)},
#  {'predictions': array([ 201757.828125], dtype=float32)},
#  {'predictions': array([ 257106.484375], dtype=float32)},
#  {'predictions': array([ 171316.40625], dtype=float32)},
#  {'predictions': array([ 203142.203125], dtype=float32)},
#  {'predictions': array([ 135076.578125], dtype=float32)},
#  {'predictions': array([ 240714.421875], dtype=float32)},
#  {'predictions': array([ 207140.421875], dtype=float32)},
#  {'predictions': array([ 190006.125], dtype=float32)},
#  {'predictions': array([ 143758.109375], dtype=float32)},
#  {'predictions': array([ 404455.25], dtype=float32)},
#  {'predictions': array([ 168799.859375], dtype=float32)},
# ...

# %%
predictions_list = []

for pred in my_pred:
    predictions_list.append(pred['predictions'])

# %%
predictions_list[1]
# Out:
# array([ 395970.3125], dtype=float32)

# %% [markdown]
# ** Calculate the RMSE. You should be able to get around 100,000 RMSE (remember that this is in the same units as the label.) Do this manually or use [sklearn.metrics](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html) **

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
mse = mean_squared_error(y_test, predictions_list)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 89997.393675584201

# %%
# Out:
# 97921.93181985477

# %% [markdown]
# # Great Job!
